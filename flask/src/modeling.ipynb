# %%
import pandas as pd

# %%
df = pd.read_csv('../data/preprocessing.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              Tweet  Label  \
# 0           0                        pagi2 udah di buat emosi :)  Anger
# 1           1  kok stabilitas negara, memange 10 thn negara t...  Anger
# 2           2                       dah lah emosi mulu liat emyu  Anger
# 3           3  aib? bodoh benar! sebelum kata aib itu muncul,...  Anger
# 4           4                            dih lu yg nyebelin bego  Anger
#
#                                      Processed_Tweet
# 0                                   pagi2 udah emosi
# 1  stabilitas negara memange 10 thn negara tdk am...
# 2                           dah emosi mulu liat emyu
# 3  aib bodoh aib muncul tindakan kekejian kau sem...
# 4                            dih lu yg nyebelin bego

# %%
df['Label'].value_counts()
# Out:
# Label
# Anger      20
# Fear       20
# Joy        20
# Love       20
# Neutral    20
# Sad        20
# Name: count, dtype: int64

# %%
df = df.astype({'Label' : 'category'})
df = df.astype({'Processed_Tweet' : 'string'})
df.dtypes
# Out:
# Unnamed: 0                  int64
# Tweet                      object
# Label                    category
# Processed_Tweet    string[python]
# dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

x = df['Processed_Tweet']
y = df['Label']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
tf_vectorizer = TfidfVectorizer()

# %%
tf_xtrain = tf_vectorizer.fit_transform(x_train)
tf_xtest = tf_vectorizer.transform(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
import sklearn.naive_bayes as nb

clf = nb.MultinomialNB(alpha=0.1)
clf.fit(tf_xtrain, y_train)
# Out:
# MultinomialNB(alpha=0.1)

# %%
predicted_clf = clf.predict(tf_xtest)

# %%
print("MultinomialNB Accuracy: ", accuracy_score(y_test, predicted_clf))
print("MultinomialNB Precision: ", precision_score(y_test, predicted_clf, average='weighted'))
print("MultinomialNB Recall: ", recall_score(y_test, predicted_clf, average='weighted'))
print("MultinomialNB f1_score: ", f1_score(y_test, predicted_clf, average='weighted'))


print(f"Confussion matrix: \n {confusion_matrix(y_test,predicted_clf)}")
print("===============================================================")
print(classification_report(y_test, predicted_clf, zero_division=0))
# Out:
# MultinomialNB Accuracy:  0.6
# MultinomialNB Precision:  0.6622222222222223
# MultinomialNB Recall:  0.6
# MultinomialNB f1_score:  0.5973015873015873
# Confussion matrix:
#  [[4 1 0 0 0 2]
#  [1 2 0 0 0 0]
#  [1 0 4 1 0 0]
#  [0 1 0 2 1 2]
#  [1 1 0 0 2 0]
#  [0 0 0 0 0 4]]
# ===============================================================
#               precision    recall  f1-score   support
#
#        Anger       0.57      0.57      0.57         7
#         Fear       0.40      0.67      0.50         3
#          Joy       1.00      0.67      0.80         6
#         Love       0.67      0.33      0.44         6
#      Neutral       0.67      0.50      0.57         4
#          Sad       0.50      1.00      0.67         4
#
#     accuracy                           0.60        30
#    macro avg       0.63      0.62      0.59        30
# weighted avg       0.66      0.60      0.60        30

# %%
import joblib

# %%
joblib.dump(clf, '../model/main_0_1.joblib')
# Out:
# ['../model/main_0_1.joblib']

# %%
joblib.dump(tf_vectorizer, '../model/mainTfidf_0_1.joblib')
# Out:
# ['../model/mainTfidf_0_1.joblib']
